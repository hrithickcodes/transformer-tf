# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
TRANSFORMER_PROJECT_PATH = r"/content/drive/MyDrive/Transformer"
os.chdir(TRANSFORMER_PROJECT_PATH)

# %%
! ls
# Out:
# colab_training_helper.ipynb  generate_inference.py  trainer.py
# config.json		     layers		    train_transformer.py
# data			     model		    transformer.py
# decoder.py		     __pycache__	    utils
# encoder.py		     runs

# %%
! nvidia-smi
# Out:
# Wed Nov 30 16:51:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! python train_transformer.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Batch: 348, Batch Loss: 0.06846839189529419, Batch Accuracy: 0.8235294222831726
# Batch: 349, Batch Loss: 0.05340242758393288, Batch Accuracy: 0.8454440832138062
# Batch: 350, Batch Loss: 0.05973215028643608, Batch Accuracy: 0.8369196057319641
# Batch: 351, Batch Loss: 0.0670446902513504, Batch Accuracy: 0.8133484125137329
# Batch: 352, Batch Loss: 0.06589146703481674, Batch Accuracy: 0.8336798548698425
# Batch: 353, Batch Loss: 0.06868184357881546, Batch Accuracy: 0.8064864873886108
# Batch: 354, Batch Loss: 0.06197760999202728, Batch Accuracy: 0.8338944911956787
# Batch: 355, Batch Loss: 0.07667724043130875, Batch Accuracy: 0.78925621509552
# Batch: 356, Batch Loss: 0.05845077335834503, Batch Accuracy: 0.8393051028251648
# Batch: 357, Batch Loss: 0.0769663006067276, Batch Accuracy: 0.79935622215271
# Batch: 358, Batch Loss: 0.07495269924402237, Batch Accuracy: 0.8126338124275208
# ...
